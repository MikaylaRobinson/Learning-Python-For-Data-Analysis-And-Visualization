# %%
import numpy as np
from numpy.random import randn
import pandas as pd

from scipy import stats

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
dataset1 = randn(100)

# %% [markdown]
# Making a default histogram

# %%
plt.hist(dataset1)
# Out:
# (array([  3.,   6.,  15.,  19.,  14.,  17.,  14.,   7.,   3.,   2.]),
#  array([-2.17601434, -1.68894393, -1.20187352, -0.71480311, -0.22773271,
#          0.2593377 ,  0.74640811,  1.23347852,  1.72054893,  2.20761934,
#          2.69468975]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

# %% [markdown]
# Changing the color of a histogram

# %%
plt.hist(dataset2,color='indianred')
# Out:
# (array([  2.,   6.,   8.,  14.,  12.,  14.,   9.,   6.,   6.,   3.]),
#  array([-2.71558376, -2.2100323 , -1.70448084, -1.19892938, -0.69337792,
#         -0.18782646,  0.317725  ,  0.82327646,  1.32882792,  1.83437938,
#          2.33993084]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Putting two datasets on the same plot. Normed is used to normalize dataset and use two sets with different amounts of data points

# %%
plt.hist(dataset1,normed=True,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,normed=True,alpha=0.5,bins=20)
# Out:
# (array([ 0.04945095,  0.04945095,  0.0989019 ,  0.1978038 ,  0.2967057 ,
#          0.0989019 ,  0.3956076 ,  0.2967057 ,  0.2967057 ,  0.2967057 ,
#          0.24725475,  0.44505855,  0.24725475,  0.1978038 ,  0.14835285,
#          0.14835285,  0.24725475,  0.04945095,  0.04945095,  0.0989019 ]),
#  array([-2.71558376, -2.46280803, -2.2100323 , -1.95725657, -1.70448084,
#         -1.45170511, -1.19892938, -0.94615365, -0.69337792, -0.44060219,
#         -0.18782646,  0.06494927,  0.317725  ,  0.57050073,  0.82327646,
#          1.07605219,  1.32882792,  1.58160365,  1.83437938,  2.08715511,
#          2.33993084]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %% [markdown]
# Joint plots

# %%
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2,kind='hex')
